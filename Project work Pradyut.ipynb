# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/riju/Downloads/checkoutstimeseries.csv')
df
# Out:
#      Unnamed: 0  Year-Month    BOOK   EBOOK  SOUNDDISC  VIDEODISC  AUDIOBOOK  \
# 0             0  2005-04-01  143053       0      37432      32157          0
# 1             1  2005-05-01  227864       0      58138      53305          0
# 2             2  2005-06-01  287908       0      70580      67821          0
# 3             3  2005-07-01  195018       0      49752      48457          0
# 4             4  2005-08-01  210033       0      55664      53192          0
# ..          ...         ...     ...     ...        ...        ...        ...
# 228         228  2024-04-01  232015  258261      13424      44527     221409
# 229         229  2024-05-01       0       0          0          0          0
# 230         230  2024-06-01       0       0          0          0          0
# 231         231  2024-07-01   82917  225241       2567      11869     195156
# 232         232  2024-08-01  182940  240663       8698      31273     209228
#
#      Other
# 0    40021
# 1    62088
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  233 non-null    int64
#  1   Year-Month  233 non-null    object
#  2   BOOK        233 non-null    int64
#  3   EBOOK       233 non-null    int64
#  4   SOUNDDISC   233 non-null    int64
#  5   VIDEODISC   233 non-null    int64
#  6   AUDIOBOOK   233 non-null    int64
#  7   Other       233 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 14.7+ KB
# None

# %%
print(df.describe())
# Out:
#        Unnamed: 0           BOOK          EBOOK      SOUNDDISC      VIDEODISC  \
# count  233.000000     233.000000     233.000000     233.000000     233.000000
# mean   116.000000  295347.785408  102797.952790   63721.175966  138379.025751
# std     67.405489   82091.596684   92157.475368   37587.766420   70917.971643
# min      0.000000       0.000000       0.000000       0.000000       0.000000
# 25%     58.000000  257218.000000    3895.000000   32987.000000   65198.000000
# 50%    116.000000  318049.000000   97810.000000   67215.000000  152627.000000
# 75%    174.000000  347835.000000  178939.000000   93251.000000  192407.000000
# max    232.000000  403791.000000  286052.000000  142699.000000  267902.000000
#
#            AUDIOBOOK         Other
# count     233.000000    233.000000
# mean    60323.064378  23961.579399
# std     66469.628629  17604.953559
# min         0.000000      0.000000
# 25%      5669.000000   8168.000000
# 50%     30971.000000  19859.000000
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Year-Month', 'BOOK', 'EBOOK', 'SOUNDDISC', 'VIDEODISC',
#        'AUDIOBOOK', 'Other'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,5))

# %%
df.plot.line(x='Year-Month', y='BOOK',label='label for Year-Month', color='blue')
plt.title('Plot of Year-Month vs BOOK')
plt.xlabel('Year-Month')
plt.ylabel('BOOK')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.plot.line(x='Year-Month', y='EBOOK',label='label for Year-Month', color='red')
plt.title('Plot of Year-Month vs EBOOK')
plt.xlabel('Year-Month')
plt.ylabel('EBOOK')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.plot.line(x='Year-Month', y='AUDIOBOOK',label='label for Year-Month', color='green')
plt.title('Plot of Year-Month vs AUDIOBOOK')
plt.xlabel('Year-Month')
plt.ylabel('AUDIOBOOK')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.plot.line(x='Year-Month', y='SOUNDDISC',label='label for Year-Month', color='black')
plt.title('Plot of Year-Month vs SOUNDDISC')
plt.xlabel('Year-Month')
plt.ylabel('SOUNDDISC')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.plot.line(x='Year-Month', y='VIDEODISC',label='label for Year-Month', color='brown')
plt.title('Plot of Year-Month vs VIDEODISC')
plt.xlabel('Year-Month')
plt.ylabel('VIDEODISC')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.plot.line(x='Year-Month', y='Other',label='label for Year-Month', color='purple')
plt.title('Plot of Year-Month vs Other')
plt.xlabel('Year-Month')
plt.ylabel('Other')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.plot.scatter(x='Year-Month', y='BOOK')
plt.show()

# %%
df.plot.scatter('Year-Month', 'EBOOK', color='red')
df.plot.scatter('Year-Month', 'AUDIOBOOK', color='grey')
df.plot.scatter('Year-Month', 'Other', color='yellow')
# Out:
# <Axes: xlabel='Year-Month', ylabel='Other'>

# %%
df.plot.scatter('Year-Month', 'SOUNDDISC', color='green')
# Out:
# <Axes: xlabel='Year-Month', ylabel='SOUNDDISC'>

# %%
df.plot.scatter('Year-Month', 'VIDEODISC', color='orange')
# Out:
# <Axes: xlabel='Year-Month', ylabel='VIDEODISC'>

# %%
df_1 = df.drop(columns=['Unnamed: 0'])

# %%
df_1.plot.hist(bins=12, alpha=1)
# Out:
# <Axes: ylabel='Frequency'>

# %%
columns=df.columns
plt.figure(figsize=(20, 5))

# %%
df_1.hist(bins=30, figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
ser=pd.Series(np.random.randn(1500))
ser.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
from pandas.plotting import bootstrap_plot
data=pd.Series(np.random.rand(2000))
bootstrap_plot(data, samples=500, color='blue');
