# %%
pip install langdetect
# Out:
# ...
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993250 sha256=c794d18416c6a67e9f1afdeeebb59f7cf64cee7d1cc9e76f8251b857bda0bbd6
#   Stored in directory: c:\users\klill\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException

# %%
# Creating a sample dataframe with both Chinese and English text
data = {
    'text_column': [
        'This is an English sentence.',
        '这是中文句子。',
        'Another English text.',
        '这是另一个中文句子。'
    ]
}

df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#                     text_column
# 0  This is an English sentence.
# 1                       这是中文句子。
# 2         Another English text.
# 3                    这是另一个中文句子。

# %%
# Assuming df is your pandas DataFrame and the column you're checking is 'text_column'
def is_english(text):
    try:
        return detect(text) == 'en'
    except LangDetectException:
        return False

# Filter DataFrame to keep only rows where the text is detected as English
df_filtered = df[df['text_column'].apply(is_english)]

# Display the filtered DataFrame
print(df_filtered)
# Out:
#                     text_column
# 0  This is an English sentence.
# 2         Another English text.

# %%
# Sample DataFrame
data = {'year_column': ['Year: 2021!', 'Year@2019', '#2020$', '2022']}
df = pd.DataFrame(data)

# Extract numeric part and convert to float
df['year_int'] = df['year_column'].str.extract(r'(\d+)').astype(int)

# Display the updated DataFrame
print(df)
# Out:
#    year_column  year_int
# 0  Year: 2021!      2021
# 1    Year@2019      2019
# 2       #2020$      2020
# 3         2022      2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
df_trimmed=pd.read_csv(r"C:\Users\klill\OneDrive - UW\Documents\UW\Data-Science-Project-2024\data\libdata_partial.csv")#,usecols=['MaterialType','CheckoutYear','CheckoutMonth','Checkouts','Title','Creator','Subjects','PublicationYear'], parse_dates={'dates':['CheckoutYear','CheckoutMonth']} )

# %%
df_filtered = df_trimmed[df_trimmed['Title'].apply(is_english)]

# %%
len(df_trimmed)
# Out:
# 50000

# %%
len(df_filtered)
# Out:
# 44377

# %%
df_filtered = df_filtered.dropna()

# %%
df_filtered['year_int'] = df_filtered['PublicationYear'].str.extract(r'(\d+)').astype(int)

# %%
df_filtered
# Out:
#        Unnamed: 0 UsageClass CheckoutType MaterialType  CheckoutYear  \
# 0               0    Digital    OverDrive    AUDIOBOOK          2022
# 3               3    Digital    OverDrive        EBOOK          2022
# 5               5    Digital    OverDrive    AUDIOBOOK          2022
# 6               6    Digital    OverDrive        EBOOK          2022
# 7               7    Digital    OverDrive        EBOOK          2022
# ...           ...        ...          ...          ...           ...
# 49995       49995   Physical      Horizon         BOOK          2022
# 49996       49996   Physical      Horizon         BOOK          2022
# 49997       49997   Physical      Horizon         BOOK          2022
# 49998       49998   Physical      Horizon     REGPRINT          2022
# 49999       49999    Digital    OverDrive        EBOOK          2022
#
#        CheckoutMonth  Checkouts  \
# 0                  8          1
# 3                  8          1
# 5                  8          3
# ...

# %%
df_filtered = df_filtered.sort_values(by='Title')

# %%
df_filtered.iloc[50:100]
# Out:
#        Unnamed: 0 UsageClass CheckoutType MaterialType  CheckoutYear  \
# 44893       44893   Physical      Horizon         BOOK          2022
# 25522       25522   Physical      Horizon         BOOK          2022
# 15033       15033   Physical      Horizon         BOOK          2022
# 27638       27638   Physical      Horizon         BOOK          2022
# 10174       10174    Digital    OverDrive        EBOOK          2022
# 2821         2821    Digital    OverDrive        EBOOK          2022
# 821           821    Digital    OverDrive        EBOOK          2022
# 2373         2373    Digital    OverDrive        EBOOK          2022
# 44466       44466    Digital    OverDrive        EBOOK          2022
# 4413         4413    Digital    OverDrive    AUDIOBOOK          2022
# 35612       35612    Digital    OverDrive        EBOOK          2022
# 46074       46074    Digital    OverDrive        EBOOK          2022
# 45135       45135   Physical      Horizon         BOOK          2022
# ...
