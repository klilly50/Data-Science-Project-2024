# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_train = pd.read_csv('../../data/FirstYearCheckouts/cleaned_train_full_2005.csv')

# %%
df_train
# Out:
#                                                     Title  \
# 0       American seafood : heritage, culture & cookery...
# 1       The runaway pea / Kjartan Poskitt & Alex Willm...
# 2                What the cat dragged in / Miranda James.
# 3       R.F.K. : a photographer's journal / Harry Benson.
# 4                                               Ice Drift
# ...                                                   ...
# 452803  When Reagan sent in the Marines : the invasion...
# 452804  Dare me [sound recording] : a novel / Megan Ab...
# 452805                  Dark queen wary : / Paul Doherty.
# 452806           Beautiful ruins : a novel / Jess Walter.
# 452807                    Beneath a Prairie Moon: A Novel
#
#                         Creator UsageClass MaterialType     Genre  \
# 0                Seaver, Barton   Physical         BOOK     other
# 1              Poskitt, Kjartan   Physical         BOOK  juvenile
# 2                James, Miranda   Physical         BOOK   mystery
# ...

# %%
sns.scatterplot(data=df_train,x='PreviousYearCheckoutsSum',y='FirstYearCheckouts',hue='MaterialType')
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Number of Checkouts from Author in Previous Year")
plt.ylabel("Total Checkouts in First Year")
plt.legend(title='Material Type',bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
sns.scatterplot(data=df_train,x='PreviousYearCheckouts',y='FirstYearCheckouts',hue='Genre')
plt.xlabel("Number of Checkouts from Author in Previous Year")
plt.ylabel("Total Checkouts in First Year")
plt.legend(title='Genre',bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
sns.barplot(data=df_train, x='MaterialType', y='FirstYearCheckouts',estimator=np.sum)
plt.title("Sum of Checkouts by Material Type")
plt.xlabel("Material Type")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df_train, x='MaterialType', y='FirstYearCheckouts')
plt.title("Mean # of Checkouts by Material Type")
plt.xlabel("Material Type")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df_train, x='Genre', y='FirstYearCheckouts',estimator=np.sum)
plt.title("Sum of Checkouts by Genre")
plt.xlabel("Genre")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df_train, x='Genre', y='FirstYearCheckouts')
plt.title("Mean # of Checkouts by Genre")
plt.xlabel("Genre")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df_train, x='UsageClass', y='FirstYearCheckouts',estimator=np.sum)
plt.title("Sum of Checkouts by Usage Class")
plt.xlabel("Usage Class")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df_train, x='UsageClass', y='FirstYearCheckouts')
plt.title("Mean # of Checkouts by Usage Class")
plt.xlabel("Usage Class")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df_train, x='CheckoutYear', y='FirstYearCheckouts')
plt.title("Mean # of Checkouts by Checkout Year")
plt.xlabel("Checkout Year")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df_train, x='CheckoutMonth', y='FirstYearCheckouts')
plt.title("Mean # of Checkouts by Checkout Month")
plt.xlabel("Checkout Month")
plt.ylabel("First Year Checkouts")
plt.xticks(rotation=45)
plt.show()

# %%
# Set up bins for the x-axis data
num_bins = 10  # Adjust this to your preference
df_train['x_bins'] = pd.cut(df_train['PreviousYearCheckouts'], bins=num_bins)

# Group by bins and calculate the sum of y-values in each bin
binned_data = df_train.groupby('x_bins')['FirstYearCheckouts'].sum().reset_index()
binned_data
# Out:
# C:\Users\klill\AppData\Local\Temp\ipykernel_33788\1007837951.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df_train.groupby('x_bins')['FirstYearCheckouts'].sum().reset_index()
#                x_bins  FirstYearCheckouts
# 0   (-34.548, 3454.8]            18662459
# 1    (3454.8, 6909.6]              911897
# 2   (6909.6, 10364.4]              247408
# 3  (10364.4, 13819.2]              168088
# 4  (13819.2, 17274.0]              119455
# 5  (17274.0, 20728.8]               65214
# 6  (20728.8, 24183.6]               44324
# 7  (24183.6, 27638.4]               20266
# 8  (27638.4, 31093.2]               53509
# 9  (31093.2, 34548.0]                5433

# %%
sns.barplot(data=binned_data, x='x_bins', y='FirstYearCheckouts')
plt.xlabel('Previous Year Checkouts Bins')
plt.ylabel('Sum of Y Values')
plt.title('Sum of Y within Each X Bin')
plt.xticks(rotation=45)  # Rotate x labels if needed
plt.show()

# %%
binned_data_NoFirstBin = binned_data.iloc[1:]
binned_data_NoFirstBin
# Out:
#                x_bins  FirstYearCheckouts
# 1    (3454.8, 6909.6]              911897
# 2   (6909.6, 10364.4]              247408
# 3  (10364.4, 13819.2]              168088
# 4  (13819.2, 17274.0]              119455
# 5  (17274.0, 20728.8]               65214
# 6  (20728.8, 24183.6]               44324
# 7  (24183.6, 27638.4]               20266
# 8  (27638.4, 31093.2]               53509
# 9  (31093.2, 34548.0]                5433

# %%
sns.barplot(data=binned_data_NoFirstBin, x='x_bins', y='FirstYearCheckouts')
plt.xlabel('Previous Year Checkouts Bins')
plt.ylabel('Sum of Y Values')
plt.title('Sum of Y within Each X Bin')
plt.xticks(rotation=45)  # Rotate x labels if needed
plt.show()
